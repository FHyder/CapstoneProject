# %%
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt

# %%
hi = pd.read_csv('MY.38362002.csv')

# %%
hi.info()
hi.drop(['ConditionName','ConditionSNOMED','PathogenName', 'PathogenTaxonID','CountryName','CountryISO', 'Admin1ISO','Admin2Name', 'CityName','PlaceOfAcquisition','DiagnosisCertainty','SourceName'], axis = 1, inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2034 entries, 0 to 2033
# Data columns (total 20 columns):
# ConditionName                  2034 non-null object
# ConditionSNOMED                2034 non-null int64
# PathogenName                   2034 non-null object
# PathogenTaxonID                2034 non-null int64
# Fatalities                     2034 non-null int64
# CountryName                    2034 non-null object
# CountryISO                     2034 non-null object
# Admin1Name                     1944 non-null object
# Admin1ISO                      1944 non-null object
# Admin2Name                     0 non-null float64
# CityName                       0 non-null float64
# PeriodStartDate                2034 non-null object
# PeriodEndDate                  2034 non-null object
# PartOfCumulativeCountSeries    2034 non-null int64
# AgeRange                       2034 non-null object
# Subpopulation                  2034 non-null object
# PlaceOfAcquisition             0 non-null float64
# DiagnosisCertainty             0 non-null float64
# SourceName                     2034 non-null object
# CountValue                     2034 non-null int64
# dtypes: float64(4), int64(5), object(11)
# memory usage: 317.9+ KB

# %%
hi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2034 entries, 0 to 2033
# Data columns (total 8 columns):
# Fatalities                     2034 non-null int64
# Admin1Name                     1944 non-null object
# PeriodStartDate                2034 non-null object
# PeriodEndDate                  2034 non-null object
# PartOfCumulativeCountSeries    2034 non-null int64
# AgeRange                       2034 non-null object
# Subpopulation                  2034 non-null object
# CountValue                     2034 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 127.2+ KB

# %%
hi = hi.dropna()

# %%
hi.head()
# Out:
#    Fatalities Admin1Name PeriodStartDate PeriodEndDate  \
# 0           0      JOHOR      1993-01-01    1993-01-31
# 1           0      JOHOR      1993-02-01    1993-02-28
# 2           0      JOHOR      1993-03-01    1993-03-31
# 3           0      JOHOR      1993-04-01    1993-04-30
# 4           0      JOHOR      1993-05-01    1993-05-31
#
#    PartOfCumulativeCountSeries AgeRange   Subpopulation  CountValue
# 0                            0    0-130  None specified          41
# 1                            0    0-130  None specified          52
# 2                            0    0-130  None specified          35
# 3                            0    0-130  None specified          45
# 4                            0    0-130  None specified          55

# %%
hi.Fatalities.value_counts()
# Out:
# 0    1944
# Name: Fatalities, dtype: int64

# %%
hi.drop('Fatalities', inplace = True, axis = 1)

# %%
hi.Subpopulation.unique()
# Out:
# array(['None specified'], dtype=object)

# %%
hi.drop('Subpopulation', inplace = True, axis = 1)

# %%
hi.PartOfCumulativeCountSeries.unique(), hi.AgeRange.unique()
# Out:
# (array([0]), array(['0-130'], dtype=object))

# %%
hi.drop(['PartOfCumulativeCountSeries', 'AgeRange'], axis = 1, inplace = True)

# %%
hi.Admin1Name.value_counts()
# Out:
# PERLIS             216
# NEGERI SEMBILAN    216
# JOHOR              216
# PAHANG             216
# PULAU PINANG       204
# KELANTAN           204
# SELANGOR           192
# PERAK              192
# SABAH              144
# SARAWAK            144
# Name: Admin1Name, dtype: int64

# %%
sum(hi.Admin1Name.value_counts().values)
# Out:
# 1944

# %%
hi
# Out:
#      Admin1Name PeriodStartDate PeriodEndDate  CountValue
# 0         JOHOR      1993-01-01    1993-01-31          41
# 1         JOHOR      1993-02-01    1993-02-28          52
# 2         JOHOR      1993-03-01    1993-03-31          35
# 3         JOHOR      1993-04-01    1993-04-30          45
# 4         JOHOR      1993-05-01    1993-05-31          55
# 5         JOHOR      1993-06-01    1993-06-30          56
# 6         JOHOR      1993-07-01    1993-07-31          67
# 7         JOHOR      1993-08-01    1993-08-31          52
# 8         JOHOR      1993-09-01    1993-09-30          54
# 9         JOHOR      1993-10-01    1993-10-31          26
# 10        JOHOR      1993-11-01    1993-11-30          16
# 11        JOHOR      1993-12-01    1993-12-31          31
# 12        JOHOR      1994-01-01    1994-01-31          17
# 13        JOHOR      1994-02-01    1994-02-28          27
# 14        JOHOR      1994-03-01    1994-03-31           9
# 15        JOHOR      1994-04-01    1994-04-30          19
# 16        JOHOR      1994-05-01    1994-05-31          21
# 17        JOHOR      1994-06-01    1994-06-30          32
# 18        JOHOR      1994-07-01    1994-07-31          68
# 19        JOHOR      1994-08-01    1994-08-31          61
# 20        JOHOR      1994-09-01    1994-09-30          69
# 21        JOHOR      1994-10-01    1994-10-31          84
# 22        JOHOR      1994-11-01    1994-11-30          70
# 23        JOHOR      1994-12-01    1994-12-31          48
# 24        JOHOR      1995-01-01    1995-01-31          54
# 25        JOHOR      1995-02-01    1995-02-28          47
# 26        JOHOR      1995-03-01    1995-03-31          62
# 27        JOHOR      1995-04-01    1995-04-30          38
# 28        JOHOR      1995-05-01    1995-05-31          72
# 29        JOHOR      1995-06-01    1995-06-30         106
# ...         ...             ...           ...         ...
# 1914   SELANGOR      2008-07-01    2008-07-31         543
# 1915   SELANGOR      2008-08-01    2008-08-31         494
# 1916   SELANGOR      2008-09-01    2008-09-30         374
# 1917   SELANGOR      2008-10-01    2008-10-31         432
# 1918   SELANGOR      2008-11-01    2008-11-30         484
# 1919   SELANGOR      2008-12-01    2008-12-31         545
# 1920   SELANGOR      2009-01-01    2009-01-31        3425
# 1921   SELANGOR      2009-02-01    2009-02-28        2658
# 1922   SELANGOR      2009-03-01    2009-03-31        2729
# 1923   SELANGOR      2009-04-01    2009-04-30        2564
# 1924   SELANGOR      2009-05-01    2009-05-31        1889
# 1925   SELANGOR      2009-06-01    2009-06-30        1570
# 1926   SELANGOR      2009-07-01    2009-07-31        1552
# 1927   SELANGOR      2009-08-01    2009-08-31        1088
# 1928   SELANGOR      2009-09-01    2009-09-30        1113
# 1929   SELANGOR      2009-10-01    2009-10-31        1050
# 1930   SELANGOR      2009-11-01    2009-11-30        1008
# 1931   SELANGOR      2009-12-01    2009-12-31        1776
# 1932   SELANGOR      2010-01-01    2010-01-31        2221
# 1933   SELANGOR      2010-02-01    2010-02-28        2403
# 1934   SELANGOR      2010-03-01    2010-03-31        2880
# 1935   SELANGOR      2010-04-01    2010-04-30        2161
# 1936   SELANGOR      2010-05-01    2010-05-31        1630
# 1937   SELANGOR      2010-06-01    2010-06-30        2007
# 1938   SELANGOR      2010-07-01    2010-07-31        1609
# 1939   SELANGOR      2010-08-01    2010-08-31        1253
# 1940   SELANGOR      2010-09-01    2010-09-30        1271
# 1941   SELANGOR      2010-10-01    2010-10-31        1119
# 1942   SELANGOR      2010-11-01    2010-11-30         998
# 1943   SELANGOR      2010-12-01    2010-12-31        1020
#
# [1944 rows x 4 columns]

# %%
hi["PeriodStartDate"]= pd.to_datetime(hi["PeriodStartDate"]) 
hi["PeriodEndDate"]= pd.to_datetime(hi["PeriodEndDate"])

# %%
hi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1944 entries, 0 to 1943
# Data columns (total 4 columns):
# Admin1Name         1944 non-null object
# PeriodStartDate    1944 non-null datetime64[ns]
# PeriodEndDate      1944 non-null datetime64[ns]
# CountValue         1944 non-null int64
# dtypes: datetime64[ns](2), int64(1), object(1)
# memory usage: 75.9+ KB

# %%
dayStart = hi.PeriodStartDate.dt.day
dayEnd = hi.PeriodEndDate.dt.day

# %%
plt.plot(dayStart)
plt.plot(dayEnd)
plt.show()

# %%
month = hi.PeriodEndDate.dt.month
day = hi.PeriodEndDate.dt.day
year = hi.PeriodEndDate.dt.year
hi.drop(['PeriodEndDate','PeriodStartDate'], axis = 1, inplace = True)
hi['month'] = month
hi['day'] = day
hi['year'] = year

# %%
hi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1944 entries, 0 to 1943
# Data columns (total 5 columns):
# Admin1Name    1944 non-null object
# CountValue    1944 non-null int64
# month         1944 non-null int64
# day           1944 non-null int64
# year          1944 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 91.1+ KB

# %%
hi.Admin1Name.unique()
# Out:
# array(['JOHOR', 'KELANTAN', 'NEGERI SEMBILAN', 'PAHANG', 'PERAK',
#        'PERLIS', 'PULAU PINANG', 'SABAH', 'SARAWAK', 'SELANGOR'],
#       dtype=object)

# %%
from darksky import forecast
key = 'd3d2e47d69b32ae4a53d871229f26f97'
Johor = key, 1.4854, 103.7618
fore = forecast(*Johor, time = dt(1993,1,31).isoformat())
fore['daily']['data'][0]['temperatureHigh'],
fore['daily']['data'][0]['cloudCover']
# Out:
# 0.81

# %%
# %%time
key = 'd3d2e47d69b32ae4a53d871229f26f97'
Johor = key, 1.4854, 103.7618
Kelantan = key, 6.1254, 102.2381 
NS = key, 2.7258, 101.9424
Pahang = key, 3.8126, 103.3256
Perak = key, 4.5921, 101.0901
Perlis = key, 6.4449, 100.2048
Pulau = key, 5.4164, 100.3327
Sabah = key, 5.9788, 116.0753
Sarawak = key, 1.5533, 110.3592
Selangor = key, 3.0738, 101.5183
loc = ['JOHOR', 'KELANTAN', 'NEGERI SEMBILAN', 'PAHANG', 'PERAK','PERLIS', 'PULAU PINANG', 'SABAH', 'SARAWAK', 'SELANGOR']
k = [Johor, Kelantan, NS, Pahang, Perak, Perlis, Pulau, Sabah, Sarawak, Selangor]
from darksky import forecast

cloudCover = []
highTemp = []
humidity = []
windSpeed = []
for i in list(range(0,5)):#list(range(len(hi))):
    if hi['Admin1Name'][i] == loc[0]:
        fore = forecast(*k[0], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        fore['daily']['data'][0]['cloudCover']
   



cloudCover = []
    highTemp = []
    humidity = []
    windSpeed = []
    if hi['Admin1Name'][i] == loc[0]:
        fore = forecast(*k[0], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        fore['daily']['data'][0]['cloudCover']
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[1]:
        fore = forecast(*k[1], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[2]:
        fore = forecast(*k[2], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[3]:
        fore = forecast(*k[3], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[4]:
        fore = forecast(*k[4], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[5]:
        fore = forecast(*k[5], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[6]:
        fore = forecast(*k[6], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[7]:
        fore = forecast(*k[7], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[8]:
        fore = forecast(*k[8], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
    elif hi['Admin1Name'][i] == loc[9]:
        fore = forecast(*k[9], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())
        cloudCover.append(fore['daily']['data'][0]['cloudCover'])
        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])
        humidity.append(fore['daily']['data'][0]['humidity'])
        windSpeed.append(fore['daily']['data'][0]['windSpeed'])
# Out:
# Traceback (most recent call last):
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-64-229a98b26b07>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', "key = 'd3d2e47d69b32ae4a53d871229f26f97'\nJohor = key, 1.4854, 103.7618\nKelantan = key, 6.1254, 102.2381 \nNS = key, 2.7258, 101.9424\nPahang = key, 3.8126, 103.3256\nPerak = key, 4.5921, 101.0901\nPerlis = key, 6.4449, 100.2048\nPulau = key, 5.4164, 100.3327\nSabah = key, 5.9788, 116.0753\nSarawak = key, 1.5533, 110.3592\nSelangor = key, 3.0738, 101.5183\nloc = ['JOHOR', 'KELANTAN', 'NEGERI SEMBILAN', 'PAHANG', 'PERAK','PERLIS', 'PULAU PINANG', 'SABAH', 'SARAWAK', 'SELANGOR']\nk = [Johor, Kelantan, NS, Pahang, Perak, Perlis, Pulau, Sabah, Sarawak, Selangor]\nfrom darksky import forecast\n\ncloudCover = []\nhighTemp = []\nhumidity = []\nwindSpeed = []\nfor i in list(range(0,5)):#list(range(len(hi))):\n    if hi['Admin1Name'][i] == loc[0]:\n        fore = forecast(*k[0], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        fore['daily']['data'][0]['cloudCover']\n   \n\n\n\ncloudCover = []\n    highTemp = []\n    humidity = []\n    windSpeed = []\n    if hi['Admin1Name'][i] == loc[0]:\n        fore = forecast(*k[0], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        fore['daily']['data'][0]['cloudCover']\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[1]:\n        fore = forecast(*k[1], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[2]:\n        fore = forecast(*k[2], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[3]:\n        fore = forecast(*k[3], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[4]:\n        fore = forecast(*k[4], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[5]:\n        fore = forecast(*k[5], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[6]:\n        fore = forecast(*k[6], time = dt(hi['year'][i],hi['month'][i],hi['day'][i]).isoformat())\n        cloudCover.append(fore['daily']['data'][0]['cloudCover'])\n        highTemp.append(fore['daily']['data'][0]['temperatureHigh'])\n        humidity.append(fore['daily']['data'][0]['humidity'])\n        windSpeed.append(fore['daily']['data'][0]['windSpeed'])\n    elif hi['Admin1Name'][i] == loc[7]:\n        fore = forecast(*k[7], time = dt(hi['year'][i],h ...
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2347, in run_cell_magic
#     result = fn(magic_arg_s, cell)
#
#   File "</anaconda3/lib/python3.6/site-packages/decorator.py:decorator-gen-61>", line 2, in time
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1256, in time
#     expr_ast = self.shell.compile.ast_parse(expr)
#
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/compilerop.py", line 100, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 29
#     highTemp = []
#     ^
# IndentationError: unexpected indent

# %%
fore['daily']['data'][0]['cloudCover']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-fbc2cc9e5fa2> in <module>
# ----> 1 fore['daily']['data'][0]['cloudCover']
#
# KeyError: 'cloudCover'

# %%
hii

# %%
hii.

# %%
k[0]
# Out:
# ('f4761a4ccedd723bbf8c71faf210651f', 1.4854, 103.7618)

# %%
for i in hi:
    print(i)
hi['Admin1Name'][0]
# Out:
# Admin1Name
# CountValue
# month
# day
# year
# 'JOHOR'

# %%
fore['daily']['icon']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-1473c1e428d8> in <module>
# ----> 1 fore['daily']['icon']
#
# NameError: name 'fore' is not defined

# %%
J = forecast(key, 1.4854, 103.7618)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-29-02bfae5c2eb0> in <module>
# ----> 1 J = forecast(key, 1.4854, 103.7618)
#
# /anaconda3/lib/python3.6/site-packages/darksky/__init__.py in forecast(key, latitude, longitude, time, timeout, **queries)
#       5
#       6 def forecast(key, latitude, longitude, time=None, timeout=None, **queries):
# ----> 7     return Forecast(key, latitude, longitude, time, timeout, **queries)
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in __init__(self, key, latitude, longitude, time, timeout, **queries)
#      15     def __init__(self, key, latitude, longitude, time=None, timeout=None, **queries):
#      16         self._parameters = dict(key=key, latitude=latitude, longitude=longitude, time=time)
# ---> 17         self.refresh(timeout, **queries)
#      18
#      19     def __setattr__(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in refresh(self, timeout, **queries)
#      52         self.response_headers = response.headers
#      53         if response.status_code is not 200:
# ---> 54             raise requests.exceptions.HTTPError('Bad response')
#      55         return super().__init__(json.loads(response.text))
#
# HTTPError: Bad response

# %%
fore['daily']['data'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f8d84f05550a> in <module>
# ----> 1 fore['daily']['data'][0]
#
# NameError: name 'fore' is not defined

# %%
c = forecast(key,12.1696, 68.9900)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-31-ba2484741243> in <module>
# ----> 1 c = forecast(key,12.1696, 68.9900)
#
# /anaconda3/lib/python3.6/site-packages/darksky/__init__.py in forecast(key, latitude, longitude, time, timeout, **queries)
#       5
#       6 def forecast(key, latitude, longitude, time=None, timeout=None, **queries):
# ----> 7     return Forecast(key, latitude, longitude, time, timeout, **queries)
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in __init__(self, key, latitude, longitude, time, timeout, **queries)
#      15     def __init__(self, key, latitude, longitude, time=None, timeout=None, **queries):
#      16         self._parameters = dict(key=key, latitude=latitude, longitude=longitude, time=time)
# ---> 17         self.refresh(timeout, **queries)
#      18
#      19     def __setattr__(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in refresh(self, timeout, **queries)
#      52         self.response_headers = response.headers
#      53         if response.status_code is not 200:
# ---> 54             raise requests.exceptions.HTTPError('Bad response')
#      55         return super().__init__(json.loads(response.text))
#
# HTTPError: Bad response

# %%
c['currently']

# %%
import world_bank_data as wb

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# 6                       Environment
# 7                  Financial Sector
# 8                            Health
# 9                    Infrastructure
# 10        Social Protection & Labor
# 11                          Poverty
# 12                   Private Sector
# 13                    Public Sector
# 14             Science & Technology
# 15               Social Development
# 16                Urban Development
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# 2   Aid effectiveness is the impact that aid has i...
# 3   Economic growth is central to economic develop...
# 4   Education is one of the most powerful instrume...
# 5   The world economy needs ever-increasing amount...
# 6   Natural and man-made environmental resources –...
# 7   An economy's financial markets are critical to...
# 8   Improving health is central to the Millennium ...
# 9   Infrastructure helps determine the success of ...
# 10  The supply of labor available in an economy in...
# 11  For countries with an active poverty monitorin...
# 12  Private markets drive economic growth, tapping...
# 13  Effective governments improve people's standar...
# 14  Technological innovation, often fueled by gove...
# 15  Data here cover child labor, gender issues, re...
# 16  Cities can be tremendously efficient. It is ea...
# 17  Gender equality is a core development objectiv...
# 18
# 19  Climate change is expected to hit developing c...
# 20  Debt statistics provide a detailed picture of ...
# 21  Trade is a key means to fight poverty and achi...

# %%
wb.get_indicators(topic = 7)
# Out:
#                                                                    name unit  \
# id
# BM.KLT.DINV.CD.WD     Foreign direct investment, net outflows (BoP, ...
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# BM.TRF.PWKR.CD.DT              Personal remittances, paid (current US$)
# BN.KLT.DINV.CD        Foreign direct investment, net (BoP, current US$)
# BN.KLT.PTXL.CD             Portfolio Investment, net (BoP, current US$)
# BX.KLT.DINV.CD.WD     Foreign direct investment, net inflows (BoP, c...
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# BX.KLT.DREM.CD.DT         Primary income on FDI, payments (current US$)
# BX.PEF.TOTL.CD.WD      Portfolio equity, net inflows (BoP, current US$)
# BX.TRF.PWKR.CD          Personal transfers, receipts (BoP, current US$)
# BX.TRF.PWKR.CD.DT          Personal remittances, received (current US$)
# BX.TRF.PWKR.DT.GD.ZS          Personal remittances, received (% of GDP)
# CM.MKT.INDX.ZG              S&P Global Equity Indices (annual % change)
# CM.MKT.LCAP.CD        Market capitalization of listed domestic compa...
# CM.MKT.LCAP.GD.ZS     Market capitalization of listed domestic compa...
# CM.MKT.LDOM.NO                         Listed domestic companies, total
# CM.MKT.TRAD.CD                 Stocks traded, total value (current US$)
# CM.MKT.TRAD.GD.ZS                 Stocks traded, total value (% of GDP)
# CM.MKT.TRNR           Stocks traded, turnover ratio of domestic shar...
# DT.NFL.BOND.CD        Portfolio investment, bonds (PPG + PNG) (NFL, ...
# FB.AST.LOAN.CB.P3     Loan accounts, commercial banks (per 1,000 adu...
# FB.AST.LOAN.MF.P3     Loan accounts, microfinance institutions (per ...
# FB.AST.NPER.ZS        Bank nonperforming loans to total gross loans (%)
# FB.ATM.TOTL.P5        Automated teller machines (ATMs) (per 100,000 ...
# FB.BNK.CAPA.ZS                         Bank capital to assets ratio (%)
# FB.CBK.BRCH.P5            Commercial bank branches (per 100,000 adults)
# FB.CBK.BRWR.P3        Borrowers from commercial banks (per 1,000 adu...
# FB.CBK.DPTR.P3        Depositors with commercial banks (per 1,000 ad...
# FB.POS.TOTL.P5             Point-of-sale terminals (per 100,000 adults)
# FD.AST.PRVT.GD.ZS     Domestic credit to private sector by banks (% ...
# ...                                                                 ...  ...
# IC.CRD.PUBL.ZS            Public credit registry coverage (% of adults)
# IC.LGL.CRED.XQ        Strength of legal rights index (0=weak to 12=s...
# NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)
# NY.GDP.DEFL.ZS.AD     GDP deflator: linked series (base year varies ...
# PA.NUS.ATLS             DEC alternative conversion factor (LCU per US$)
# PA.NUS.FCRF           Official exchange rate (LCU per US$, period av...
# PX.REX.REER             Real effective exchange rate index (2010 = 100)
# SM.EMI.TERT.ZS        Emigration rate of tertiary educated (% of tot...
# SM.POP.NETM                                               Net migration
# SM.POP.TOTL                          International migrant stock, total
# SM.POP.TOTL.ZS            International migrant stock (% of population)
# WP_time_01.1             Account at a financial institution (% age 15+)
# WP_time_01.2          Account at a financial institution, male (% ag...
# WP_time_01.3          Account at a financial institution, female (% ...
# WP_time_01.8          Account at a financial institution, income, po...
# WP_time_01.9          Account at a financial institution, income, ri...
# WP_time_10.1                                   Account (% age 15+) [ts]
# WP_time_10.2                             Account, male (% age 15+) [ts]
# WP_time_10.3                           Account, female (% age 15+) [ts]
# WP_time_10.4                  Account, young adults (% ages 15-24) [ts]
# WP_time_10.5                    Account, older adults (% ages 25+) [ts]
# WP_time_10.6          Account, primary education or less (% ages 15+...
# WP_time_10.7          Account, secondary education or more (% ages 1...
# WP_time_10.8             Account, income, poorest 40% (% ages 15+) [ts]
# WP_time_10.9             Account, income, richest 60% (% ages 15+) [ts]
# WP15163_4.1                                  Mobile account (% age 15+)
# WP15163_4.2                            Mobile account, male (% age 15+)
# WP15163_4.3                          Mobile account, female (% age 15+)
# WP15163_4.8            Mobile account, income, poorest 40% (% ages 15+)
# WP15163_4.9            Mobile account, income, richest 60% (% ages 15+)
#
#                                             source  \
# id
# BM.KLT.DINV.CD.WD     World Development Indicators
# BM.KLT.DINV.WD.GD.ZS  World Development Indicators
# BM.TRF.PWKR.CD.DT     World Development Indicators
# BN.KLT.DINV.CD        World Development Indicators
# BN.KLT.PTXL.CD        World Development Indicators
# BX.KLT.DINV.CD.WD     World Development Indicators
# BX.KLT.DINV.WD.GD.ZS  World Development Indicators
# BX.KLT.DREM.CD.DT     World Development Indicators
# BX.PEF.TOTL.CD.WD     World Development Indicators
# BX.TRF.PWKR.CD        World Development Indicators
# BX.TRF.PWKR.CD.DT     World Development Indicators
# BX.TRF.PWKR.DT.GD.ZS  World Development Indicators
# CM.MKT.INDX.ZG        World Development Indicators
# CM.MKT.LCAP.CD        World Development Indicators
# CM.MKT.LCAP.GD.ZS     World Development Indicators
# CM.MKT.LDOM.NO        World Development Indicators
# CM.MKT.TRAD.CD        World Development Indicators
# CM.MKT.TRAD.GD.ZS     World Development Indicators
# CM.MKT.TRNR           World Development Indicators
# DT.NFL.BOND.CD        World Development Indicators
# FB.AST.LOAN.CB.P3            WDI Database Archives
# FB.AST.LOAN.MF.P3            WDI Database Archives
# FB.AST.NPER.ZS        World Development Indicators
# FB.ATM.TOTL.P5        World Development Indicators
# FB.BNK.CAPA.ZS        World Development Indicators
# FB.CBK.BRCH.P5        World Development Indicators
# FB.CBK.BRWR.P3        World Development Indicators
# FB.CBK.DPTR.P3        World Development Indicators
# FB.POS.TOTL.P5               WDI Database Archives
# FD.AST.PRVT.GD.ZS     World Development Indicators
# ...                                            ...
# IC.CRD.PUBL.ZS        World Development Indicators
# IC.LGL.CRED.XQ        World Development Indicators
# NY.GDP.DEFL.KD.ZG.AD  World Development Indicators
# NY.GDP.DEFL.ZS.AD     World Development Indicators
# PA.NUS.ATLS           World Development Indicators
# PA.NUS.FCRF           World Development Indicators
# PX.REX.REER           World Development Indicators
# SM.EMI.TERT.ZS               WDI Database Archives
# SM.POP.NETM           World Development Indicators
# SM.POP.TOTL           World Development Indicators
# SM.POP.TOTL.ZS        World Development Indicators
# WP_time_01.1                 WDI Database Archives
# WP_time_01.2                 WDI Database Archives
# WP_time_01.3                 WDI Database Archives
# WP_time_01.8                 WDI Database Archives
# WP_time_01.9                 WDI Database Archives
# WP_time_10.1                 WDI Database Archives
# WP_time_10.2                 WDI Database Archives
# WP_time_10.3                 WDI Database Archives
# WP_time_10.4                 WDI Database Archives
# WP_time_10.5                 WDI Database Archives
# WP_time_10.6                 WDI Database Archives
# WP_time_10.7                 WDI Database Archives
# WP_time_10.8                 WDI Database Archives
# WP_time_10.9                 WDI Database Archives
# WP15163_4.1                  WDI Database Archives
# WP15163_4.2                  WDI Database Archives
# WP15163_4.3                  WDI Database Archives
# WP15163_4.8                  WDI Database Archives
# WP15163_4.9                  WDI Database Archives
#
#                                                              sourceNote  \
# id
# BM.KLT.DINV.CD.WD     Foreign direct investment refers to direct inv...
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment refers to direct inv...
# BM.TRF.PWKR.CD.DT     Personal remittances comprise personal transfe...
# BN.KLT.DINV.CD        Foreign direct investment are the net inflows ...
# BN.KLT.PTXL.CD        Portfolio investment covers transactions in eq...
# BX.KLT.DINV.CD.WD     Foreign direct investment refers to direct inv...
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment are the net inflows ...
# BX.KLT.DREM.CD.DT     Primary income on foreign direct investment co...
# BX.PEF.TOTL.CD.WD     Portfolio equity includes net inflows from equ...
# BX.TRF.PWKR.CD        Personal transfers consist of all current tran...
# BX.TRF.PWKR.CD.DT     Personal remittances comprise personal transfe...
# BX.TRF.PWKR.DT.GD.ZS  Personal remittances comprise personal transfe...
# CM.MKT.INDX.ZG        S&P Global Equity Indices measure the U.S. dol...
# CM.MKT.LCAP.CD        Market capitalization (also known as market va...
# CM.MKT.LCAP.GD.ZS     Market capitalization (also known as market va...
# CM.MKT.LDOM.NO        Listed domestic companies, including foreign c...
# CM.MKT.TRAD.CD        The value of shares traded is the total number...
# CM.MKT.TRAD.GD.ZS     The value of shares traded is the total number...
# CM.MKT.TRNR           Turnover ratio is the value of domestic shares...
# DT.NFL.BOND.CD        Bonds are securities issued with a fixed rate ...
# FB.AST.LOAN.CB.P3     Loan accounts at commercial banks include loan...
# FB.AST.LOAN.MF.P3     Microfinance institutions are institutions who...
# FB.AST.NPER.ZS        Bank nonperforming loans to total gross loans ...
# FB.ATM.TOTL.P5        Automated teller machines are computerized tel...
# FB.BNK.CAPA.ZS        Bank capital to assets is the ratio of bank ca...
# FB.CBK.BRCH.P5        Commercial bank branches are retail locations ...
# FB.CBK.BRWR.P3        Borrowers from commercial banks are the report...
# FB.CBK.DPTR.P3        Depositors with commercial banks are the repor...
# FB.POS.TOTL.P5        Point-of-sale terminals are the equipment used...
# FD.AST.PRVT.GD.ZS     Domestic credit to private sector by banks ref...
# ...                                                                 ...
# IC.CRD.PUBL.ZS        Public credit registry coverage reports the nu...
# IC.LGL.CRED.XQ        Strength of legal rights index measures the de...
# NY.GDP.DEFL.KD.ZG.AD  Inflation as measured by the annual growth rat...
# NY.GDP.DEFL.ZS.AD     The GDP implicit deflator is calculated as the...
# PA.NUS.ATLS           The DEC alternative conversion factor is the u...
# PA.NUS.FCRF           Official exchange rate refers to the exchange ...
# PX.REX.REER           Real effective exchange rate is the nominal ef...
# SM.EMI.TERT.ZS        Emigration rate of tertiary educated shows the...
# SM.POP.NETM           Net migration is the net total of migrants dur...
# SM.POP.TOTL           International migrant stock is the number of p...
# SM.POP.TOTL.ZS        International migrant stock is the number of p...
# WP_time_01.1          Denotes the percentage of respondents who repo...
# WP_time_01.2          Denotes the percentage of respondents who repo...
# WP_time_01.3          Denotes the percentage of respondents who repo...
# WP_time_01.8          Denotes the percentage of respondents who repo...
# WP_time_01.9          Denotes the percentage of respondents who repo...
# WP_time_10.1          Denotes the percentage of respondents who repo...
# WP_time_10.2          Denotes the percentage of respondents who repo...
# WP_time_10.3          Denotes the percentage of respondents who repo...
# WP_time_10.4          Denotes the percentage of respondents who repo...
# WP_time_10.5          Denotes the percentage of respondents who repo...
# WP_time_10.6          Denotes the percentage of respondents who repo...
# WP_time_10.7          Denotes the percentage of respondents who repo...
# WP_time_10.8          Denotes the percentage of respondents who repo...
# WP_time_10.9          Denotes the percentage of respondents who repo...
# WP15163_4.1           Denotes the percentage of respondents who repo...
# WP15163_4.2           Denotes the percentage of respondents who repo...
# WP15163_4.3           Denotes the percentage of respondents who repo...
# WP15163_4.8           Denotes the percentage of respondents who repo...
# WP15163_4.9           Denotes the percentage of respondents who repo...
#
#                                                      sourceOrganization  \
# id
# BM.KLT.DINV.CD.WD     International Monetary Fund, Balance of Paymen...
# BM.KLT.DINV.WD.GD.ZS  International Monetary Fund, Balance of Paymen...
# BM.TRF.PWKR.CD.DT     World Bank staff estimates based on IMF balanc...
# BN.KLT.DINV.CD        International Monetary Fund, Balance of Paymen...
# BN.KLT.PTXL.CD        International Monetary Fund, Balance of Paymen...
# BX.KLT.DINV.CD.WD     International Monetary Fund, Balance of Paymen...
# BX.KLT.DINV.WD.GD.ZS  International Monetary Fund, International Fin...
# BX.KLT.DREM.CD.DT     International Monetary Fund, Balance of Paymen...
# BX.PEF.TOTL.CD.WD     International Monetary Fund, Balance of Paymen...
# BX.TRF.PWKR.CD        International Monetary Fund, Balance of Paymen...
# BX.TRF.PWKR.CD.DT     World Bank staff estimates based on IMF balanc...
# BX.TRF.PWKR.DT.GD.ZS  World Bank staff estimates based on IMF balanc...
# CM.MKT.INDX.ZG        Standard & Poor's, Global Stock Markets Factbo...
# CM.MKT.LCAP.CD                  World Federation of Exchanges database.
# CM.MKT.LCAP.GD.ZS               World Federation of Exchanges database.
# CM.MKT.LDOM.NO                  World Federation of Exchanges database.
# CM.MKT.TRAD.CD                  World Federation of Exchanges database.
# CM.MKT.TRAD.GD.ZS               World Federation of Exchanges database.
# CM.MKT.TRNR                     World Federation of Exchanges database.
# DT.NFL.BOND.CD               World Bank, International Debt Statistics.
# FB.AST.LOAN.CB.P3     Consultative Group to Assist the Poor and the ...
# FB.AST.LOAN.MF.P3     Consultative Group to Assist the Poor and the ...
# FB.AST.NPER.ZS        International Monetary Fund, Global Financial ...
# FB.ATM.TOTL.P5        International Monetary Fund, Financial Access ...
# FB.BNK.CAPA.ZS        International Monetary Fund, Global Financial ...
# FB.CBK.BRCH.P5        International Monetary Fund, Financial Access ...
# FB.CBK.BRWR.P3        International Monetary Fund, Financial Access ...
# FB.CBK.DPTR.P3        International Monetary Fund, Financial Access ...
# FB.POS.TOTL.P5        Consultative Group to Assist the Poor and the ...
# FD.AST.PRVT.GD.ZS     International Monetary Fund, International Fin...
# ...                                                                 ...
# IC.CRD.PUBL.ZS        World Bank, Doing Business project (http://www...
# IC.LGL.CRED.XQ        World Bank, Doing Business project (http://www...
# NY.GDP.DEFL.KD.ZG.AD  World Bank staff estimates based on World Bank...
# NY.GDP.DEFL.ZS.AD     World Bank staff estimates based on World Bank...
# PA.NUS.ATLS           International Monetary Fund, International Fin...
# PA.NUS.FCRF           International Monetary Fund, International Fin...
# PX.REX.REER           International Monetary Fund, International Fin...
# SM.EMI.TERT.ZS        Frédéric Docquier, B. Lindsay Lowell, and Abde...
# SM.POP.NETM           United Nations Population Division. World Popu...
# SM.POP.TOTL           United Nations Population Division, Trends in ...
# SM.POP.TOTL.ZS        United Nations Population Division, Trends in ...
# WP_time_01.1                                 Demirguc-Kunt et al., 2015
# WP_time_01.2                                 Demirguc-Kunt et al., 2015
# WP_time_01.3                                 Demirguc-Kunt et al., 2015
# WP_time_01.8                                 Demirguc-Kunt et al., 2015
# WP_time_01.9                                 Demirguc-Kunt et al., 2015
# WP_time_10.1          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.2          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.3          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.4          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.5          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.6          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.7          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.8          Demirguc-Kunt et al., 2015, Global Financial I...
# WP_time_10.9          Demirguc-Kunt et al., 2015, Global Financial I...
# WP15163_4.1                                  Demirguc-Kunt et al., 2015
# WP15163_4.2                                  Demirguc-Kunt et al., 2015
# WP15163_4.3                                  Demirguc-Kunt et al., 2015
# WP15163_4.8                                  Demirguc-Kunt et al., 2015
# WP15163_4.9                                  Demirguc-Kunt et al., 2015
#
#                                                                  topics
# id
# BM.KLT.DINV.CD.WD                    Economy & Growth,Financial Sector
# BM.KLT.DINV.WD.GD.ZS                 Economy & Growth,Financial Sector
# BM.TRF.PWKR.CD.DT                    Economy & Growth,Financial Sector
# BN.KLT.DINV.CD                       Economy & Growth,Financial Sector
# BN.KLT.PTXL.CD                       Economy & Growth,Financial Sector
# BX.KLT.DINV.CD.WD      Economy & Growth,Financial Sector ,External Debt
# BX.KLT.DINV.WD.GD.ZS  Economy & Growth,Financial Sector ,Climate Change
# BX.KLT.DREM.CD.DT      Economy & Growth,Financial Sector ,External Debt
# BX.PEF.TOTL.CD.WD      Economy & Growth,Financial Sector ,External Debt
# BX.TRF.PWKR.CD                       Economy & Growth,Financial Sector
# BX.TRF.PWKR.CD.DT      Economy & Growth,Financial Sector ,External Debt
# BX.TRF.PWKR.DT.GD.ZS                 Economy & Growth,Financial Sector
# CM.MKT.INDX.ZG                                        Financial Sector
# CM.MKT.LCAP.CD                                        Financial Sector
# CM.MKT.LCAP.GD.ZS                                     Financial Sector
# CM.MKT.LDOM.NO                                        Financial Sector
# CM.MKT.TRAD.CD                                        Financial Sector
# CM.MKT.TRAD.GD.ZS                                     Financial Sector
# CM.MKT.TRNR                                           Financial Sector
# DT.NFL.BOND.CD                          Financial Sector ,External Debt
# FB.AST.LOAN.CB.P3                                     Financial Sector
# FB.AST.LOAN.MF.P3                                     Financial Sector
# FB.AST.NPER.ZS                                        Financial Sector
# FB.ATM.TOTL.P5                                        Financial Sector
# FB.BNK.CAPA.ZS                                        Financial Sector
# FB.CBK.BRCH.P5                                        Financial Sector
# FB.CBK.BRWR.P3                                        Financial Sector
# FB.CBK.DPTR.P3                                        Financial Sector
# FB.POS.TOTL.P5                                        Financial Sector
# FD.AST.PRVT.GD.ZS                                     Financial Sector
# ...                                                                 ...
# IC.CRD.PUBL.ZS          Financial Sector ,Private Sector,Public Sector
# IC.LGL.CRED.XQ          Financial Sector ,Private Sector,Public Sector
# NY.GDP.DEFL.KD.ZG.AD                                  Financial Sector
# NY.GDP.DEFL.ZS.AD                                     Financial Sector
# PA.NUS.ATLS                          Economy & Growth,Financial Sector
# PA.NUS.FCRF                                           Financial Sector
# PX.REX.REER                                           Financial Sector
# SM.EMI.TERT.ZS                     Education ,Financial Sector ,Health
# SM.POP.NETM                Financial Sector ,Health ,Aid Effectiveness
# SM.POP.TOTL                                   Financial Sector ,Health
# SM.POP.TOTL.ZS                                Financial Sector ,Health
# WP_time_01.1                                          Financial Sector
# WP_time_01.2                                   Financial Sector ,Gender
# WP_time_01.3                                   Financial Sector ,Gender
# WP_time_01.8                                          Financial Sector
# WP_time_01.9                                          Financial Sector
# WP_time_10.1                                          Financial Sector
# WP_time_10.2                                          Financial Sector
# WP_time_10.3                                          Financial Sector
# WP_time_10.4                                          Financial Sector
# WP_time_10.5                                          Financial Sector
# WP_time_10.6                                          Financial Sector
# WP_time_10.7                                          Financial Sector
# WP_time_10.8                                          Financial Sector
# WP_time_10.9                                          Financial Sector
# WP15163_4.1                                           Financial Sector
# WP15163_4.2                                    Financial Sector ,Gender
# WP15163_4.3                                    Financial Sector ,Gender
# WP15163_4.8                                           Financial Sector
# WP15163_4.9                                           Financial Sector
#
# [195 rows x 6 columns]

# %%
indicators = {'NY.GDP.PCAP.CD'}

# %%
wb.get_series('NY.GDP.PCAP.CD', date = '1993', country='MYS')
# Out:
# Country   Series                        Year
# Malaysia  GDP per capita (current US$)  1993    3433.143378
# Name: NY.GDP.PCAP.CD, dtype: float64

# %%
BOSTON = key, 42.3601, -71.0589
from datetime import datetime as dt
t = dt(2013, 5, 6, 12).isoformat()
boston = forecast(*BOSTON, time=t)
boston.time
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-28-2fad30784448> in <module>
#       2 from datetime import datetime as dt
#       3 t = dt(2013, 5, 6, 12).isoformat()
# ----> 4 boston = forecast(*BOSTON, time=t)
#       5 boston.time
#
# /anaconda3/lib/python3.6/site-packages/darksky/__init__.py in forecast(key, latitude, longitude, time, timeout, **queries)
#       5
#       6 def forecast(key, latitude, longitude, time=None, timeout=None, **queries):
# ----> 7     return Forecast(key, latitude, longitude, time, timeout, **queries)
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in __init__(self, key, latitude, longitude, time, timeout, **queries)
#      15     def __init__(self, key, latitude, longitude, time=None, timeout=None, **queries):
#      16         self._parameters = dict(key=key, latitude=latitude, longitude=longitude, time=time)
# ---> 17         self.refresh(timeout, **queries)
#      18
#      19     def __setattr__(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/darksky/forecast.py in refresh(self, timeout, **queries)
#      52         self.response_headers = response.headers
#      53         if response.status_code is not 200:
# ---> 54             raise requests.exceptions.HTTPError('Bad response')
#      55         return super().__init__(json.loads(response.text))
#
# HTTPError: Bad response

# %%
import pandas as pd 
import requests
import json 


url = 'https://api.darksky.net/forecast/%s/43.0481221,-76.147424' % (key)
response = requests.get(url)
weather_data = response.json()

# %%
weather_data
# Out:
# {'code': 403, 'error': 'daily usage limit exceeded'}
